# %%
# import dependencies
import pandas as pd
import numpy as np
# read in csv file
data = pd.read_csv('../static/data/new_ final_data.csv')
# display first 10 rows of the dataframe
data.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2  Afghanistan          AFG
# 3  Afghanistan          AFG
# 4  Afghanistan          AFG
#
#                                          Series Name        Series Code  \
# 0  Literacy rate, adult female (% of females ages...  SE.ADT.LITR.FE.ZS
# 1  Literacy rate, adult total (% of people ages 1...     SE.ADT.LITR.ZS
# 2  Literacy rate, adult male (% of males ages 15 ...  SE.ADT.LITR.MA.ZS
# 3                 Agricultural land (% of land area)     AG.LND.AGRI.ZS
# 4  Agriculture, forestry, and fishing, value adde...     NV.AGR.TOTL.ZS
#
#       2003 [YR2003]     2004 [YR2004]    2005 [YR2005]     2006 [YR2006]  \
# 0                ..                ..               ..                ..
# 1                ..                ..               ..                ..
# 2                ..                ..               ..                ..
# 3  58.0838047927878  58.1512656578201  58.134400441562   58.123668031216
# 4  37.4188554431481  29.7210671376957  31.114854912062  28.6359685844686
#
#       2007 [YR2007]     2008 [YR2008]  ...     2013 [YR2013]  \
# 0                ..                ..  ...                ..
# 1                ..                ..  ...                ..
# 2                ..                ..  ...                ..
# 3   58.129800837128   58.132867240084  ...   58.123668031216
# 4  30.1050113574013  24.8922700059742  ...  22.8106627361766
#
#       2014 [YR2014]     2015 [YR2015]     2016 [YR2016]     2017 [YR2017]  \
# 0                ..                ..                ..                ..
# 1                ..                ..                ..                ..
# 2                ..                ..                ..                ..
# 3   58.123668031216   58.123668031216   58.123668031216   58.123668031216
# 4  22.1370413719574  20.6343227166798  25.7403140364582  26.4201990834448
#
#       2018 [YR2018]     2019 [YR2019]     2020 [YR2020]     2021 [YR2021]  \
# 0                ..                ..                ..  22.6007804870605
# 1                ..                ..                ..   37.266040802002
# 2                ..                ..                ..  52.0634307861328
# 3  58.2769881790166  58.2769881790166  58.7415482268525  58.7415482268525
# 4  22.0428967527575  25.7739707394105  29.9755825210461  33.5976188725451
#
#   2022 [YR2022]
# 0            ..
# 1            ..
# 2            ..
# 3            ..
# 4            ..
#
# [5 rows x 24 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3911 entries, 0 to 3910
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   3908 non-null   object
#  1   Country Code   3906 non-null   object
#  2   Series Name    3906 non-null   object
#  3   Series Code    3906 non-null   object
#  4   2003 [YR2003]  3906 non-null   object
#  5   2004 [YR2004]  3906 non-null   object
#  6   2005 [YR2005]  3906 non-null   object
#  7   2006 [YR2006]  3906 non-null   object
#  8   2007 [YR2007]  3906 non-null   object
#  9   2008 [YR2008]  3906 non-null   object
#  10  2009 [YR2009]  3906 non-null   object
#  11  2010 [YR2010]  3906 non-null   object
#  12  2011 [YR2011]  3906 non-null   object
#  13  2012 [YR2012]  3906 non-null   object
#  14  2013 [YR2013]  3906 non-null   object
#  15  2014 [YR2014]  3906 non-null   object
#  16  2015 [YR2015]  3906 non-null   object
#  17  2016 [YR2016]  3906 non-null   object
#  18  2017 [YR2017]  3906 non-null   object
#  19  2018 [YR2018]  3906 non-null   object
#  20  2019 [YR2019]  3906 non-null   object
#  21  2020 [YR2020]  3906 non-null   object
#  22  2021 [YR2021]  3906 non-null   object
#  23  2022 [YR2022]  3906 non-null   object
# dtypes: object(24)
# memory usage: 733.4+ KB

# %%
data.isnull()
data.dropna()
# Out:
#      Country Name Country Code  \
# 0     Afghanistan          AFG
# 1     Afghanistan          AFG
# 2     Afghanistan          AFG
# 3     Afghanistan          AFG
# 4     Afghanistan          AFG
# ...           ...          ...
# 3901     Zimbabwe          ZWE
# 3902     Zimbabwe          ZWE
# 3903     Zimbabwe          ZWE
# 3904     Zimbabwe          ZWE
# 3905     Zimbabwe          ZWE
#
#                                             Series Name        Series Code  \
# 0     Literacy rate, adult female (% of females ages...  SE.ADT.LITR.FE.ZS
# 1     Literacy rate, adult total (% of people ages 1...     SE.ADT.LITR.ZS
# 2     Literacy rate, adult male (% of males ages 15 ...  SE.ADT.LITR.MA.ZS
# 3                    Agricultural land (% of land area)     AG.LND.AGRI.ZS
# 4     Agriculture, forestry, and fishing, value adde...     NV.AGR.TOTL.ZS
# ...                                                 ...                ...
# 3901  Government expenditure on education, total (% ...  SE.XPD.TOTL.GD.ZS
# 3902  Current health expenditure per capita (current...  SH.XPD.CHEX.PC.CD
# 3903              Stocks traded, total value (% of GDP)  CM.MKT.TRAD.GD.ZS
# 3904                                  GDP (current US$)     NY.GDP.MKTP.CD
# 3905                              GDP growth (annual %)  NY.GDP.MKTP.KD.ZG
#
#           2003 [YR2003]      2004 [YR2004]      2005 [YR2005]  \
# 0                    ..                 ..                 ..
# 1                    ..                 ..                 ..
# 2                    ..                 ..                 ..
# 3      58.0838047927878   58.1512656578201    58.134400441562
# 4      37.4188554431481   29.7210671376957    31.114854912062
# ...                 ...                ...                ...
# 3901                 ..                 ..                 ..
# 3902                 ..                 ..                 ..
# 3903                 ..                 ..                 ..
# 3904         5727591800         5805598400         5755215200
# 3905  -16.9950747276622  -5.80753802273949  -5.71108370650353
#
#           2006 [YR2006]      2007 [YR2007]      2008 [YR2008]  ...  \
# 0                    ..                 ..                 ..  ...
# 1                    ..                 ..                 ..  ...
# 2                    ..                 ..                 ..  ...
# 3       58.123668031216    58.129800837128    58.132867240084  ...
# 4      28.6359685844686   30.1050113574013   24.8922700059742  ...
# ...                 ...                ...                ...  ...
# 3901                 ..                 ..                 ..  ...
# 3902                 ..                 ..                 ..  ...
# 3903                 ..                 ..                 ..  ...
# 3904         5443896500         5291950100         4415702800  ...
# 3905  -3.46149518781378  -3.65332683535506  -17.6689463301054  ...
#
#          2013 [YR2013]     2014 [YR2014]     2015 [YR2015]      2016 [YR2016]  \
# 0                   ..                ..                ..                 ..
# 1                   ..                ..                ..                 ..
# 2                   ..                ..                ..                 ..
# 3      58.123668031216   58.123668031216   58.123668031216    58.123668031216
# 4     22.8106627361766  22.1370413719574  20.6343227166798   25.7403140364582
# ...                ...               ...               ...                ...
# 3901  5.99597978591919  6.13835000991821                ..                 ..
# 3902      100.13693237      114.44429779      105.09803009       106.18969727
# 3903                ..                ..                ..                 ..
# 3904       19091020000       19495519600       19963120600        20548678100
# 3905   3.1967308868621  1.48454262162193  2.02364999592871  0.900955396308504
#
#          2017 [YR2017]     2018 [YR2018]      2019 [YR2019]  \
# 0                   ..                ..                 ..
# 1                   ..                ..                 ..
# 2                   ..                ..                 ..
# 3      58.123668031216  58.2769881790166   58.2769881790166
# 4     26.4201990834448  22.0428967527575   25.7739707394105
# ...                ...               ...                ...
# 3901  5.81877994537354  2.05048990249634                 ..
# 3902       92.25431061      114.63359833        54.80850601
# 3903                ..                ..                 ..
# 3904  17584890936.6523  34156069918.0609   21832234921.1762
# 3905  4.08026390333053  5.00986678330221  -6.33244642559313
#
#           2020 [YR2020]     2021 [YR2021]     2022 [YR2022]
# 0                    ..  22.6007804870605                ..
# 1                    ..   37.266040802002                ..
# 2                    ..  52.0634307861328                ..
# 3      58.7415482268525  58.7415482268525                ..
# 4      29.9755825210461  33.5976188725451                ..
# ...                 ...               ...               ...
# 3901                 ..                ..                ..
# 3902        50.67650986                ..                ..
# 3903                 ..                ..                ..
# 3904   21509698406.6618  28371238665.8646  27366627153.0852
# 3905  -7.81695061846828  8.46801690894254  6.52237528740794
#
# [3906 rows x 24 columns]

# %%
data.isnull()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3911 entries, 0 to 3910
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   3908 non-null   object
#  1   Country Code   3906 non-null   object
#  2   Series Name    3906 non-null   object
#  3   Series Code    3906 non-null   object
#  4   2003 [YR2003]  3906 non-null   object
#  5   2004 [YR2004]  3906 non-null   object
#  6   2005 [YR2005]  3906 non-null   object
#  7   2006 [YR2006]  3906 non-null   object
#  8   2007 [YR2007]  3906 non-null   object
#  9   2008 [YR2008]  3906 non-null   object
#  10  2009 [YR2009]  3906 non-null   object
#  11  2010 [YR2010]  3906 non-null   object
#  12  2011 [YR2011]  3906 non-null   object
#  13  2012 [YR2012]  3906 non-null   object
#  14  2013 [YR2013]  3906 non-null   object
#  15  2014 [YR2014]  3906 non-null   object
#  16  2015 [YR2015]  3906 non-null   object
#  17  2016 [YR2016]  3906 non-null   object
#  18  2017 [YR2017]  3906 non-null   object
#  19  2018 [YR2018]  3906 non-null   object
#  20  2019 [YR2019]  3906 non-null   object
#  21  2020 [YR2020]  3906 non-null   object
#  22  2021 [YR2021]  3906 non-null   object
#  23  2022 [YR2022]  3906 non-null   object
# dtypes: object(24)
# memory usage: 733.4+ KB

# %%
data.describe()
# Out:
#        Country Name Country Code  \
# count          3908         3906
# unique          219          217
# top     Afghanistan          AFG
# freq             18           18
#
#                                               Series Name        Series Code  \
# count                                                3906               3906
# unique                                                 18                 18
# top     Literacy rate, adult female (% of females ages...  SE.ADT.LITR.FE.ZS
# freq                                                  217                217
#
#        2003 [YR2003] 2004 [YR2004] 2005 [YR2005] 2006 [YR2006] 2007 [YR2007]  \
# count           3906          3906          3906          3906          3906
# unique          2671          2711          2713          2739          2757
# top               ..            ..            ..            ..            ..
# freq            1231          1191          1190          1164          1146
#
#        2008 [YR2008]  ... 2013 [YR2013] 2014 [YR2014] 2015 [YR2015]  \
# count           3906  ...          3906          3906          3906
# unique          2781  ...          2832          2877          2846
# top               ..  ...            ..            ..            ..
# freq            1122  ...          1071          1026          1058
#
#        2016 [YR2016] 2017 [YR2017] 2018 [YR2018] 2019 [YR2019] 2020 [YR2020]  \
# count           3906          3906          3906          3906          3906
# unique          2814          2811          2825          2775          2758
# top               ..            ..            ..            ..            ..
# freq            1091          1093          1080          1128          1146
#
#        2021 [YR2021] 2022 [YR2022]
# count           3906          3906
# unique          2358          1984
# top               ..            ..
# freq            1532          1918
#
# [4 rows x 24 columns]

# %%
data.replace('..', np.nan, inplace=True)

# %%
data.dropna(inplace=True)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1683 entries, 9 to 3905
# Data columns (total 24 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   1683 non-null   object
#  1   Country Code   1683 non-null   object
#  2   Series Name    1683 non-null   object
#  3   Series Code    1683 non-null   object
#  4   2003 [YR2003]  1683 non-null   object
#  5   2004 [YR2004]  1683 non-null   object
#  6   2005 [YR2005]  1683 non-null   object
#  7   2006 [YR2006]  1683 non-null   object
#  8   2007 [YR2007]  1683 non-null   object
#  9   2008 [YR2008]  1683 non-null   object
#  10  2009 [YR2009]  1683 non-null   object
#  11  2010 [YR2010]  1683 non-null   object
#  12  2011 [YR2011]  1683 non-null   object
#  13  2012 [YR2012]  1683 non-null   object
#  14  2013 [YR2013]  1683 non-null   object
#  15  2014 [YR2014]  1683 non-null   object
#  16  2015 [YR2015]  1683 non-null   object
#  17  2016 [YR2016]  1683 non-null   object
#  18  2017 [YR2017]  1683 non-null   object
#  19  2018 [YR2018]  1683 non-null   object
#  20  2019 [YR2019]  1683 non-null   object
#  21  2020 [YR2020]  1683 non-null   object
#  22  2021 [YR2021]  1683 non-null   object
#  23  2022 [YR2022]  1683 non-null   object
# dtypes: object(24)
# memory usage: 328.7+ KB

# %%
data.to_csv("../static/data/cleaned_data.csv", index=False)

# %%
cleaned_df = pd.read_csv("../static/data/cleaned_data.csv")

# %%
cleaned_df.head()
# Out:
#   Country Name Country Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series Name     Series Code  \
# 0                                  Population, total     SP.POP.TOTL
# 1                       Population growth (annual %)     SP.POP.GROW
# 2  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
# 3              Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG
# 4           Imports of goods and services (% of GDP)  NE.IMP.GNFS.ZS
#
#    2003 [YR2003]  2004 [YR2004]  2005 [YR2005]  2006 [YR2006]  2007 [YR2007]  \
# 0   2.264513e+07   2.355355e+07   2.441119e+07   2.544294e+07   2.590330e+07
# 1   7.541019e+00   3.933178e+00   3.576508e+00   4.139678e+00   1.793196e+00
# 2   2.197826e+01   2.053749e+01   1.884531e+01   1.770835e+01   1.715362e+01
# 3   4.840026e-01   2.280019e+00   2.366582e+00   2.370728e+00   2.932682e+00
# 4   4.617317e+01   4.482963e+01   4.785936e+01   4.905748e+01   5.495421e+01
#
#    2008 [YR2008]  ...  2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  \
# 0   2.642720e+07  ...   3.154121e+07   3.271621e+07   3.375350e+07
# 1   2.002333e+00  ...   3.466788e+00   3.657576e+00   3.121341e+00
# 2   1.683705e+01  ...   1.956516e+01   1.999018e+01   1.978021e+01
# 3   3.320871e+00  ...   1.937621e+00   1.625865e+00   1.896174e+00
# 4   5.214933e+01  ...   4.695740e+01   4.719484e+01   4.453362e+01
#
#    2016 [YR2016]  2017 [YR2017]  2018 [YR2018]  2019 [YR2019]  2020 [YR2020]  \
# 0   3.463621e+07   3.564342e+07   3.668678e+07   3.776950e+07   3.897223e+07
# 1   2.581549e+00   2.866492e+00   2.885208e+00   2.908529e+00   3.134747e+00
# 2   1.984999e+01   1.902213e+01   1.842950e+01   1.838933e+01   1.922522e+01
# 3   1.275432e+00   1.986661e+00   2.028060e+00   1.411091e+00   1.620887e+00
# 4   4.583196e+01   4.662445e+01   4.523623e+01   4.497492e+01   3.717194e+01
#
#    2021 [YR2021]  2022 [YR2022]
# 0   4.009946e+07   4.112877e+07
# 1   2.851358e+00   2.534498e+00
# 2   1.835813e+01   1.862282e+01
# 3   2.041472e+00   6.725203e+00
# 4   4.470882e+01   4.775426e+01
#
# [5 rows x 24 columns]

# %%
# Convert columns with years to numeric
year_columns = cleaned_df.columns[4:]
cleaned_df[year_columns] = cleaned_df[year_columns].apply(pd.to_numeric, errors='coerce')
# Melt the DataFrame
melted_data = pd.melt(cleaned_df, id_vars=['Country Name', 'Country Code', 'Series Name', 'Series Code'], var_name='Year', value_name='Value')
# Extract only the year from the "Year" column
melted_data['Year'] = melted_data['Year'].str.extract('(\d+)')
# Convert the "Year" column to numeric type
melted_data['Year'] = pd.to_numeric(melted_data['Year'], errors='coerce')
# Replace spaces in column names with underscores
melted_data.columns = melted_data.columns.str.replace(' ', '_')
# Display the melted DataFrame
print(melted_data.head())
# Out:
#   Country_Name Country_Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series_Name     Series_Code  Year  \
# 0                                  Population, total     SP.POP.TOTL  2003
# 1                       Population growth (annual %)     SP.POP.GROW  2003
# 2  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS  2003
# 3              Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG  2003
# 4           Imports of goods and services (% of GDP)  NE.IMP.GNFS.ZS  2003
#
#           Value
# 0  2.264513e+07
# 1  7.541019e+00
# 2  2.197826e+01
# 3  4.840026e-01
# 4  4.617317e+01

# %%
melted_data.head()
# Out:
#   Country_Name Country_Code  \
# 0  Afghanistan          AFG
# 1  Afghanistan          AFG
# 2      Albania          ALB
# 3      Albania          ALB
# 4      Albania          ALB
#
#                                          Series_Name     Series_Code  Year  \
# 0                                  Population, total     SP.POP.TOTL  2003
# 1                       Population growth (annual %)     SP.POP.GROW  2003
# 2  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS  2003
# 3              Inflation, consumer prices (annual %)  FP.CPI.TOTL.ZG  2003
# 4           Imports of goods and services (% of GDP)  NE.IMP.GNFS.ZS  2003
#
#           Value
# 0  2.264513e+07
# 1  7.541019e+00
# 2  2.197826e+01
# 3  4.840026e-01
# 4  4.617317e+01

# %%
melted_data.to_csv('../static/data/final_data.csv', index=False)
