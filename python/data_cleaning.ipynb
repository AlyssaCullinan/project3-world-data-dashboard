# %%
# import dependencies
import pandas as pd
import numpy as np
# read in csv file
data = pd.read_csv('../static/data/worldbank_global_indicators_2013_2022.csv')
# display first 10 rows of the dataframe
data.head()
# Out:
#   Country Name Country Code  \
# 0    Argentina          ARG
# 1    Argentina          ARG
# 2    Argentina          ARG
# 3    Argentina          ARG
# 4    Argentina          ARG
#
#                                          Series Name     Series Code  \
# 0  Age dependency ratio (% of working-age populat...     SP.POP.DPND
# 1                         Agricultural land (sq. km)  AG.LND.AGRI.K2
# 2  Agriculture, forestry, and fishing, value adde...  NV.AGR.TOTL.ZS
# 3  Annual freshwater withdrawals, agriculture (% ...  ER.H2O.FWAG.ZS
# 4  Annual freshwater withdrawals, domestic (% of ...  ER.H2O.FWDM.ZS
#
#       2013 [YR2013]     2014 [YR2014]     2015 [YR2015]     2016 [YR2016]  \
# 0  56.0868723571096  55.9732762411572  55.8644592427226  55.7543621214315
# 1           1229374           1211889           1207394           1189899
# 2  6.05291843670451  6.71270351428559   5.1566859021408  6.26456582010254
# 3      73.928004235      73.928004235      73.928004235      73.928004235
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19101 entries, 0 to 19100
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   19098 non-null  object
#  1   Country Code   19096 non-null  object
#  2   Series Name    19096 non-null  object
#  3   Series Code    19096 non-null  object
#  4   2013 [YR2013]  19096 non-null  object
#  5   2014 [YR2014]  19096 non-null  object
#  6   2015 [YR2015]  19096 non-null  object
#  7   2016 [YR2016]  19096 non-null  object
#  8   2017 [YR2017]  19096 non-null  object
#  9   2018 [YR2018]  19096 non-null  object
#  10  2019 [YR2019]  19096 non-null  object
#  11  2020 [YR2020]  19096 non-null  object
#  12  2021 [YR2021]  19096 non-null  object
#  13  2022 [YR2022]  19096 non-null  object
# dtypes: object(14)
# memory usage: 2.0+ MB

# %%
data.isnull()
data.dropna()
# Out:
#       Country Name Country Code  \
# 0        Argentina          ARG
# 1        Argentina          ARG
# 2        Argentina          ARG
# 3        Argentina          ARG
# 4        Argentina          ARG
# ...            ...          ...
# 19091     Zimbabwe          ZWE
# 19092     Zimbabwe          ZWE
# 19093     Zimbabwe          ZWE
# 19094     Zimbabwe          ZWE
# 19095     Zimbabwe          ZWE
#
#                                              Series Name        Series Code  \
# 0      Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 1                             Agricultural land (sq. km)     AG.LND.AGRI.K2
# 2      Agriculture, forestry, and fishing, value adde...     NV.AGR.TOTL.ZS
# 3      Annual freshwater withdrawals, agriculture (% ...     ER.H2O.FWAG.ZS
# 4      Annual freshwater withdrawals, domestic (% of ...     ER.H2O.FWDM.ZS
# ...                                                  ...                ...
# ...

# %%
data.isnull()
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19101 entries, 0 to 19100
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   19098 non-null  object
#  1   Country Code   19096 non-null  object
#  2   Series Name    19096 non-null  object
#  3   Series Code    19096 non-null  object
#  4   2013 [YR2013]  19096 non-null  object
#  5   2014 [YR2014]  19096 non-null  object
#  6   2015 [YR2015]  19096 non-null  object
#  7   2016 [YR2016]  19096 non-null  object
#  8   2017 [YR2017]  19096 non-null  object
#  9   2018 [YR2018]  19096 non-null  object
#  10  2019 [YR2019]  19096 non-null  object
#  11  2020 [YR2020]  19096 non-null  object
#  12  2021 [YR2021]  19096 non-null  object
#  13  2022 [YR2022]  19096 non-null  object
# dtypes: object(14)
# memory usage: 2.0+ MB

# %%
data.describe()
# Out:
#        Country Name Country Code  \
# count         19098        19096
# unique          219          217
# top       Argentina          ARG
# freq             88           88
#
#                                               Series Name  Series Code  \
# count                                               19096        19096
# unique                                                 88           88
# top     Age dependency ratio (% of working-age populat...  SP.POP.DPND
# freq                                                  217          217
#
#        2013 [YR2013] 2014 [YR2014] 2015 [YR2015] 2016 [YR2016] 2017 [YR2017]  \
# count          19096         19096         19096         19096         19096
# unique         12162         12268         11520         11550         11054
# top               ..            ..            ..            ..            ..
# freq            5540          5288          6082          5996          6786
#
# ...

# %%
data.replace('..', np.nan, inplace=True)

# %%
data.dropna(inplace=True)

data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 4762 entries, 0 to 19093
# Data columns (total 14 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Country Name   4762 non-null   object
#  1   Country Code   4762 non-null   object
#  2   Series Name    4762 non-null   object
#  3   Series Code    4762 non-null   object
#  4   2013 [YR2013]  4762 non-null   object
#  5   2014 [YR2014]  4762 non-null   object
#  6   2015 [YR2015]  4762 non-null   object
#  7   2016 [YR2016]  4762 non-null   object
#  8   2017 [YR2017]  4762 non-null   object
#  9   2018 [YR2018]  4762 non-null   object
#  10  2019 [YR2019]  4762 non-null   object
#  11  2020 [YR2020]  4762 non-null   object
#  12  2021 [YR2021]  4762 non-null   object
#  13  2022 [YR2022]  4762 non-null   object
# dtypes: object(14)
# memory usage: 558.0+ KB

# %%
data.to_csv("../static/data/cleaned_data.csv", index=False)

# %%
cleaned_df = pd.read_csv("../static/data/cleaned_data.csv")

# %%
cleaned_df.head()
# Out:
#   Country Name Country Code  \
# 0    Argentina          ARG
# 1    Argentina          ARG
# 2    Argentina          ARG
# 3    Argentina          ARG
# 4    Argentina          ARG
#
#                                          Series Name        Series Code  \
# 0  Age dependency ratio (% of working-age populat...        SP.POP.DPND
# 1  Agriculture, forestry, and fishing, value adde...     NV.AGR.TOTL.ZS
# 2           Exports of goods and services (% of GDP)     NE.EXP.GNFS.ZS
# 3  Foreign direct investment, net inflows (BoP, c...  BX.KLT.DINV.CD.WD
# 4                                  GDP (current US$)     NY.GDP.MKTP.CD
#
#    2013 [YR2013]  2014 [YR2014]  2015 [YR2015]  2016 [YR2016]  2017 [YR2017]  \
# 0   5.608687e+01   5.597328e+01   5.586446e+01   5.575436e+01   5.561124e+01
# 1   6.052918e+00   6.712704e+00   5.156686e+00   6.264566e+00   5.231622e+00
# 2   1.461717e+01   1.440548e+01   1.070565e+01   1.252710e+01   1.132028e+01
# ...

# %%
# Convert columns with years to numeric
year_columns = cleaned_df.columns[4:]
cleaned_df[year_columns] = cleaned_df[year_columns].apply(pd.to_numeric, errors='coerce')
# Melt the DataFrame
melted_data = pd.melt(cleaned_df, id_vars=['Country Name', 'Country Code', 'Series Name', 'Series Code'], var_name='Year', value_name='Value')
# Extract only the year from the "Year" column
melted_data['Year'] = melted_data['Year'].str.extract('(\d+)')
# Convert the "Year" column to numeric type
melted_data['Year'] = pd.to_numeric(melted_data['Year'], errors='coerce')
# Replace spaces in column names with underscores
melted_data.columns = melted_data.columns.str.replace(' ', '_')
# Display the melted DataFrame
print(melted_data.head())
# Out:
#   Country_Name Country_Code  \
# 0    Argentina          ARG
# 1    Argentina          ARG
# 2    Argentina          ARG
# 3    Argentina          ARG
# 4    Argentina          ARG
#
#                                          Series_Name        Series_Code  Year  \
# 0  Age dependency ratio (% of working-age populat...        SP.POP.DPND  2013
# 1  Agriculture, forestry, and fishing, value adde...     NV.AGR.TOTL.ZS  2013
# 2           Exports of goods and services (% of GDP)     NE.EXP.GNFS.ZS  2013
# 3  Foreign direct investment, net inflows (BoP, c...  BX.KLT.DINV.CD.WD  2013
# 4                                  GDP (current US$)     NY.GDP.MKTP.CD  2013
#
#           Value
# 0  5.608687e+01
# 1  6.052918e+00
# 2  1.461717e+01
# 3  9.821662e+09
# 4  5.520251e+11

# %%
melted_data.head()
# Out:
#   Country_Name Country_Code  \
# 0    Argentina          ARG
# 1    Argentina          ARG
# 2    Argentina          ARG
# 3    Argentina          ARG
# 4    Argentina          ARG
#
#                                          Series_Name        Series_Code  Year  \
# 0  Age dependency ratio (% of working-age populat...        SP.POP.DPND  2013
# 1  Agriculture, forestry, and fishing, value adde...     NV.AGR.TOTL.ZS  2013
# 2           Exports of goods and services (% of GDP)     NE.EXP.GNFS.ZS  2013
# 3  Foreign direct investment, net inflows (BoP, c...  BX.KLT.DINV.CD.WD  2013
# 4                                  GDP (current US$)     NY.GDP.MKTP.CD  2013
#
#           Value
# 0  5.608687e+01
# 1  6.052918e+00
# 2  1.461717e+01
# 3  9.821662e+09
# 4  5.520251e+11

# %%
melted_data.to_csv('../static/data/final_data.csv', index=False)
